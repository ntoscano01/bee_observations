# %%
# Import Python packages
import pandas as pd

# %%
df = pd.read_csv('observations-248024.csv')
df.head(3)
# Out:
#           id                          observed_on_string observed_on  \
# 0  104054851                                 1/1/22 7:15      1/1/22
# 1  104055292  Sat Jan 01 2022 07:54:04 GMT+1100 (GMT+11)      1/1/22
# 2  104060936                                1/1/22 11:08      1/1/22
#
#             time_observed_at   time_zone  user_id user_login  \
# 0  2022-01-01 08:15:29 +0100         UTC  4602402   mf_smith
# 1  2021-12-31 21:54:04 +0100     Magadan  1947915     suecee
# 2  2021-12-31 23:08:47 +0100  Wellington  3775937    sfwatts
#
#                   created_at                 updated_at quality_grade  ...  \
# 0  2021-12-31 21:52:05 +0100  2022-02-14 22:22:37 +0100      needs_id  ...
# 1  2021-12-31 21:57:48 +0100  2022-01-18 23:55:01 +0100      needs_id  ...
# 2  2021-12-31 23:14:55 +0100  2022-04-25 03:48:49 +0100      research  ...
#
#   geoprivacy taxon_geoprivacy coordinates_obscured positioning_method  \
# ...

# %%
df = df.drop(columns=['created_at','updated_at','observed_on_string','time_zone','geoprivacy','taxon_geoprivacy',
                      'positioning_method','positioning_device','private_place_guess',
                     'private_latitude','private_longitude','time_observed_at', 'sound_url','tag_list',
                     'positional_accuracy','public_positional_accuracy','coordinates_obscured',
                     'num_identification_agreements','captive_cultivated','oauth_application_id',
                      'num_identification_disagreements','species_guess','quality_grade'])

# %%
df = df[df['latitude'].notna()]

# %%
df['observed_on'] = pd.to_datetime(df['observed_on'])

# %%
df.dtypes
# Out:
# id                            int64
# observed_on          datetime64[ns]
# user_id                       int64
# user_login                   object
# license                      object
# url                          object
# image_url                    object
# description                  object
# place_guess                  object
# latitude                    float64
# longitude                   float64
# scientific_name              object
# common_name                  object
# iconic_taxon_name            object
# taxon_id                      int64
# dtype: object

# %%
df.head(3)
# Out:
#           id observed_on  user_id user_login   license  \
# 0  104054851  2022-01-01  4602402   mf_smith  CC-BY-NC
# 1  104055292  2022-01-01  1947915     suecee  CC-BY-NC
# 2  104060936  2022-01-01  3775937    sfwatts  CC-BY-NC
#
#                                                  url  \
# 0  https://www.inaturalist.org/observations/10405...
# 1  https://www.inaturalist.org/observations/10405...
# 2  https://www.inaturalist.org/observations/10406...
#
#                                            image_url  \
# 0  https://inaturalist-open-data.s3.amazonaws.com...
# 1  https://inaturalist-open-data.s3.amazonaws.com...
# 2  https://inaturalist-open-data.s3.amazonaws.com...
#
#                                          description  \
# 0  Native bee on cos lettuce flowers. Very active...
# 1                                                NaN
# 2  Never seen a wasp with the diamond type stripe...
#
#                                          place_guess   latitude   longitude  \
# ...

# %%
df.to_csv('observations_248024_clean.csv', sep='\t')
